# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scanpy as sc
import os
import scvi
import sys 
import os
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib import patches as mpatches
import numpy as np
from scipy.sparse import csr_matrix
from scipy.stats import ks_2samp
import anndata
import scanpy
import string
import seaborn as sns
import h5py
import tifffile
import fs
from fs import open_fs
from matplotlib_scalebar.scalebar import ScaleBar
from tqdm import tqdm

mpl.rcParams.update(mpl.rcParamsDefault) #Reset rcParams to default
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']  # Colors in this style

import gseapy
from gseapy.plot import barplot, dotplot

# %%
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Arial"

# %% [markdown]
# # REACTOME HC VS CPI COLITIS UPREGULATED

# %%
###B cells


qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/B cells.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/B cells.csv')

qqq = dotplot(enr.res2d, title='B cells',cmap='plasma', top_term = 10, size=32, figsize=(4,4), show_ring=True)

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_B cells.pdf',bbox_inches="tight")
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %%
###CD4T

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/CD4T.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/CD4T.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=48, figsize=(4,4), show_ring=True, title='CD4T')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_CD4T.pdf',bbox_inches="tight")
# Out:
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped

# %%
###CD8T

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/CD8T.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/CD8T.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=9, figsize=(4,4), show_ring=True, title='CD8T')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_CD8T.pdf',bbox_inches="tight")

# %%
###Cycling

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/Cycling.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Cycling.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=4.5, figsize=(4,4), show_ring=True, title='Cycling')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_Cycling.pdf',bbox_inches="tight")

# %%
###Endothelial

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/Endothelial.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Endothelial.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=15, figsize=(4,4), show_ring=True, title='Endothelial')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_Endothelial.pdf',bbox_inches="tight")

# %%
###Enteric neural

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/Enteric neural.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Enteric neural.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=12, figsize=(4,4), show_ring=True, title='Enteric neural')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_Enteric neural.pdf',bbox_inches="tight")

# %%
###Epithelial

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/Epithelial.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Epithelial.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=160, figsize=(4,4), show_ring=True, title='Epithelial')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_Epithelial.pdf',bbox_inches="tight")

# %%
###GD T cells

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/GD T cells.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/GD T cells.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=12, figsize=(4,4), show_ring=True, title='GD T cells')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_GD T cells.pdf',bbox_inches="tight")

# %%
###ILC3

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/ILC3.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/ILC3.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=40, figsize=(4,4), show_ring=True, title='ILC3')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_ILC3.pdf',bbox_inches="tight")

# %%
###Mesenchymal Stromal

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/Mesenchymal Stromal.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Mesenchymal Stromal.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=6, figsize=(4,4), show_ring=True, title='Mesenchymal Stromal')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_Mesenchymal Stromal.pdf',bbox_inches="tight")

# %%
###Myeloid

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/Myeloid.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Myeloid.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=13, figsize=(4,4), show_ring=True, title='Myeloid')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_Myeloid.pdf',bbox_inches="tight")

# %%
###Plasma cells

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/Plasma cells.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Plasma cells.csv')

qqq = dotplot(enr.res2d,cmap='viridis_r', top_term = 10, size=4, figsize=(4,4), show_ring=True, title='Plasma cells')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_Plasma cells.pdf',bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [106], in <cell line: 9>()
#       5 #enr.results.head(10)
#       7 enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Plasma cells.csv')
# ----> 9 qqq = dotplot(enr.res2d,cmap='viridis_r', top_term = 10, size=4, figsize=(4,4), show_ring=True, title='Plasma cells')
#      11 qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_Plasma cells.pdf',bbox_inches="tight")
#
# File ~\miniconda3\envs\cxg\lib\site-packages\gseapy\plot.py:1150, in dotplot(df, column, x, y, x_order, y_order, title, cutoff, top_term, size, figsize, cmap, ofname, xticklabels_rot, yticklabels_rot, marker, show_ring, **kwargs)
#    1147     warnings.warn("group is deprecated; use x instead", DeprecationWarning, 2)
#    1148     return
# -> 1150 dot = DotPlot(
# ...

# %%
###CD8T RM

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/CD8T RM.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/CD8T RM.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=9, figsize=(4,4), show_ring=True, title='CD8T RM')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_CD8T RM.pdf',bbox_inches="tight")

# %%
###cDC2

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/cDC2.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/cDC2.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=18, figsize=(4,4), show_ring=True, title='cDC2')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_cDC2.pdf',bbox_inches="tight")

# %%
###Epithelial absorptive colonocyte

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/input csvs/Epithelial absorptive colonocyte.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Epithelial absorptive colonocyte.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=16, figsize=(4,4), show_ring=True, title='Epithelial absorptive colonocyte')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA POSITIVE FC/Reactome2022_UP_Epithelial absorptive colonocyte.pdf',bbox_inches="tight")

# %% [markdown]
# # HC vs CPI colitis downregulated

# %%
###B cells

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/B cells.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/B cells.csv')

qqq = dotplot(enr.res2d, title='B cells',cmap='viridis', top_term = 10, size=16, figsize=(4,4), show_ring=True)

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_B cells.pdf',bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [113], in <cell line: 9>()
#       5 #enr.results.head(10)
#       7 enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/B cells.csv')
# ----> 9 qqq = dotplot(enr.res2d, title='B cells',cmap='viridis', top_term = 10, size=16, figsize=(4,4), show_ring=True)
#      11 qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_B cells.pdf',bbox_inches="tight")
#
# File ~\miniconda3\envs\cxg\lib\site-packages\gseapy\plot.py:1150, in dotplot(df, column, x, y, x_order, y_order, title, cutoff, top_term, size, figsize, cmap, ofname, xticklabels_rot, yticklabels_rot, marker, show_ring, **kwargs)
#    1147     warnings.warn("group is deprecated; use x instead", DeprecationWarning, 2)
#    1148     return
# -> 1150 dot = DotPlot(
#    1151     df=df,
# ...

# %%
###CD4T

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/CD4T.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/CD4T.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=8, figsize=(4,4), show_ring=True, title='CD4T')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_CD4T.pdf',bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [114], in <cell line: 9>()
#       5 #enr.results.head(10)
#       7 enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/CD4T.csv')
# ----> 9 qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=8, figsize=(4,4), show_ring=True, title='CD4T')
#      11 qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_CD4T.pdf',bbox_inches="tight")
#
# File ~\miniconda3\envs\cxg\lib\site-packages\gseapy\plot.py:1150, in dotplot(df, column, x, y, x_order, y_order, title, cutoff, top_term, size, figsize, cmap, ofname, xticklabels_rot, yticklabels_rot, marker, show_ring, **kwargs)
#    1147     warnings.warn("group is deprecated; use x instead", DeprecationWarning, 2)
#    1148     return
# -> 1150 dot = DotPlot(
#    1151     df=df,
#    1152     x=x,
# ...

# %%
###CD8T

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/CD8T.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/CD8T.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=19, figsize=(4,4), show_ring=True, title='CD8T')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_CD8T.pdf',bbox_inches="tight")

# %%
###Cycling

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/Cycling.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Cycling.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=7, figsize=(4,4), show_ring=True, title='Cycling')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_Cycling.pdf',bbox_inches="tight")

# %%
###Endothelial

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/Endothelial.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Endothelial.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=24, figsize=(4,4), show_ring=True, title='Endothelial')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_Endothelial.pdf',bbox_inches="tight")

# %%
###Enteric neural

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/Enteric neural.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Enteric neural.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=15, figsize=(4,4), show_ring=True, title='Enteric neural')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_Enteric neural.pdf',bbox_inches="tight")

# %%
###Epithelial

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/Epithelial.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Epithelial.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=4, figsize=(4,4), show_ring=True, title='Epithelial')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_Epithelial.pdf',bbox_inches="tight")
# Out:
# C:\Users\joshu\miniconda3\envs\cxg\lib\site-packages\fontTools\misc\py23.py:11: DeprecationWarning: The py23 module has been deprecated and will be removed in a future release. Please update your code.
#   warnings.warn(

# %%
###GD T cells

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/GD T cells.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/GD T cells.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=28, figsize=(4,4), show_ring=True, title='GD T cells')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_GD T cells.pdf',bbox_inches="tight")

# %%
###ILC3

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/ILC3.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/ILC3.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=44, figsize=(4,4), show_ring=True, title='ILC3')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_ILC3.pdf',bbox_inches="tight")

# %%
###Mesenchymal Stromal

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/Mesenchymal Stromal.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Mesenchymal Stromal.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=12, figsize=(4,4), show_ring=True, title='Mesenchymal Stromal')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_Mesenchymal Stromal.pdf',bbox_inches="tight")

# %%
###Myeloid

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/Myeloid.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Myeloid.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=12, figsize=(4,4), show_ring=True, title='Myeloid')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_Myeloid.pdf',bbox_inches="tight")

# %%
###Plasma cells

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/Plasma cells.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Plasma cells.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=20, figsize=(4,4), show_ring=True, title='Plasma cells')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_Plasma cells.pdf',bbox_inches="tight")

# %%
###CD8T RM

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/CD8T RM.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/CD8T RM.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=20, figsize=(4,4), show_ring=True, title='CD8T RM')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_CD8T RM.pdf',bbox_inches="tight")

# %%
###cDC2

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/cDC2.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/cDC2.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=26, figsize=(4,4), show_ring=True, title='cDC2')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_cDC2.pdf',bbox_inches="tight")

# %%
###Epithelial absorptive colonocyte

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/input csvs/Epithelial absorptive colonocyte.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Epithelial absorptive colonocyte.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=4.5, figsize=(4,4), show_ring=True, title='Epithelial absorptive colonocyte')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvCPIcolitis GSEA NEG FC/Reactome2022_Epithelial absorptive colonocyte.pdf',bbox_inches="tight")

# %% [markdown]
# # COMPARISON TO UC

# %%
###

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC NEG FC/input csvs/CD8T.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC NEG FC/CD8T.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=4, figsize=(4,4), show_ring=True, title='CD8T')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC NEG FC/Reactome2022_CD8T.pdf',bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [142], in <cell line: 9>()
#       5 #enr.results.head(10)
#       7 enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC NEG FC/CD8T.csv')
# ----> 9 qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=4, figsize=(4,4), show_ring=True, title='CD8T')
#      11 qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC NEG FC/Reactome2022_CD8T.pdf',bbox_inches="tight")
#
# File ~\miniconda3\envs\cxg\lib\site-packages\gseapy\plot.py:1150, in dotplot(df, column, x, y, x_order, y_order, title, cutoff, top_term, size, figsize, cmap, ofname, xticklabels_rot, yticklabels_rot, marker, show_ring, **kwargs)
#    1147     warnings.warn("group is deprecated; use x instead", DeprecationWarning, 2)
#    1148     return
# -> 1150 dot = DotPlot(
#    1151     df=df,
#    1152     x=x,
#    1153     y=y,
# ...

# %%
###

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC NEG FC/input csvs/Epithelial.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC NEG FC/Epithelial.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=7, figsize=(4,4), show_ring=True, title='Epithelial')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC NEG FC/Reactome2022_Epithelial.pdf',bbox_inches="tight")

# %%
###

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC NEG FC/input csvs/Mesenchymal stromal.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC NEG FC/Mesenchymal stromal.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=19, figsize=(4,4), show_ring=True, title='Mesenchymal stromal')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC NEG FC/Reactome2022_Mesenchymal stromal.pdf',bbox_inches="tight")

# %%
###

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC POS FC/input csvs/CD8T.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC POS FC/CD8T.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=24, figsize=(4,4), show_ring=True, title='CD8T')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC POS FC/Reactome2022_CD8T.pdf',bbox_inches="tight")

# %%
###

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC POS FC/input csvs/Epithelial.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC POS FC/Epithelial.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=80, figsize=(4,4), show_ring=True, title='Epithelial')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC POS FC/Reactome2022_Epithelial.pdf',bbox_inches="tight")

# %%
###

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC POS FC/input csvs/Mesenchymal stromal.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC POS FC/Mesenchymal stromal.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=40, figsize=(4,4), show_ring=True, title='Mesenchymal stromal')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/HvUC POS FC/Reactome2022_Mesenchymal stromal.pdf',bbox_inches="tight")

# %%
###CD8T

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis POS FC/input csvs/CD8T.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis POS FC/CD8T.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=8, figsize=(4,4), show_ring=True, title='CD8T')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis POS FC/Reactome2022_CD8T.pdf',bbox_inches="tight")

# %%
###Epithelial

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis POS FC/input csvs/Epithelial.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis POS FC/Epithelial.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=4, figsize=(4,4), show_ring=True, title='Epithelial')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis POS FC/Reactome2022_Epithelial.pdf',bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [158], in <cell line: 3>()
#       1 ###Epithelial
# ----> 3 qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis POS FC/input csvs/Epithelial.csv')
#       4 enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#       5 #enr.results.head(10)
#
# File ~\miniconda3\envs\cxg\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
###Mesenchymal stromal

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis POS FC/input csvs/Mesenchymal stromal.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis POS FC/Mesenchymal stromal.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=7, figsize=(4,4), show_ring=True, title='Mesenchymal stromal')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis POS FC/Reactome2022_Mesenchymal stromal.pdf',bbox_inches="tight")

# %%
###CD8T

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis NEG FC/input csvs/CD8T.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis NEG FC/CD8T.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=14, figsize=(4,4), show_ring=True, title='CD8T')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis NEG FC/Reactome2022_CD8T.pdf',bbox_inches="tight")

# %%
###Epithelial

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis NEG FC/input csvs/Epithelial.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis NEG FC/Epithelial.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=8, figsize=(4,4), show_ring=True, title='Epithelial')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis NEG FC/Reactome2022_Epithelial.pdf',bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [163], in <cell line: 4>()
#       1 ###Epithelial
#       3 qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis NEG FC/input csvs/Epithelial.csv')
# ----> 4 enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#       5 #enr.results.head(10)
#       7 enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis NEG FC/Epithelial.csv')
#
# File ~\miniconda3\envs\cxg\lib\site-packages\gseapy\__init__.py:554, in enrichr(gene_list, gene_sets, organism, outdir, background, cutoff, format, figsize, top_term, no_plot, verbose)
#     552 # set organism
#     553 enr.set_organism()
# --> 554 enr.run()
#     556 return enr
#
# File ~\miniconda3\envs\cxg\lib\site-packages\gseapy\enrichr.py:612, in Enrichr.run(self)
#     608         shortID, res = self.get_results_with_background(
# ...

# %%
###Mesenchymal stromal

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis NEG FC/input csvs/Mesenchymal stromal.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis NEG FC/Mesenchymal stromal.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=18, figsize=(4,4), show_ring=True, title='Mesenchymal stromal')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/UCvCPIcolitis NEG FC/Reactome2022_Mesenchymal stromal.pdf',bbox_inches="tight")

# %% [markdown]
# # PD1 vs combo

# %%
###

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo neg/input csvs/CD8T.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo neg/CD8T.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=8, figsize=(4,4), show_ring=True, title='CD8T')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo neg/Reactome2022_CD8T.pdf',bbox_inches="tight")

# %%
###

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo neg/input csvs/Myeloid.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo neg/Myeloid.csv')

qqq = dotplot(enr.res2d,cmap='viridis', top_term = 10, size=10, figsize=(4,4), show_ring=True, title='Myeloid')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo neg/Reactome2022_Myeloid.pdf',bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [42], in <cell line: 9>()
#       5 #enr.results.head(10)
#       7 enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo neg/Myeloid.csv')
# ----> 9 qqq = dotplot(enr.res2d,cmap='viridis_r', top_term = 10, size=10, figsize=(4,4), show_ring=True, title='Myeloid')
#      11 qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo neg/Reactome2022_Myeloid.pdf',bbox_inches="tight")
#
# File ~\miniconda3\envs\cxg\lib\site-packages\gseapy\plot.py:1150, in dotplot(df, column, x, y, x_order, y_order, title, cutoff, top_term, size, figsize, cmap, ofname, xticklabels_rot, yticklabels_rot, marker, show_ring, **kwargs)
#    1147     warnings.warn("group is deprecated; use x instead", DeprecationWarning, 2)
#    1148     return
# -> 1150 dot = DotPlot(
#    1151     df=df,
#    1152     x=x,
# ...

# %%
###

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo pos/input csvs/CD8T.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo pos/CD8T.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=24, figsize=(4,4), show_ring=True, title='CD8T')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo pos/Reactome2022_CD8T.pdf',bbox_inches="tight")

# %%
###

qq = pd.read_csv('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo pos/input csvs/Myeloid.csv')
enr = gseapy.enrichr(gene_list=qq,gene_sets='Reactome_2022')
#enr.results.head(10)

enr.results.to_csv('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo pos/Myeloid.csv')

qqq = dotplot(enr.res2d,cmap='plasma', top_term = 10, size=6, figsize=(4,4), show_ring=True, title='Myeloid')

qqqq=qqq.figure.savefig('c:/Users/joshu/Desktop/GSEA heatmaps/PD1vcombo pos/Reactome2022_Myeloid.pdf',bbox_inches="tight")
